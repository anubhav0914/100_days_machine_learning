# %%
# Normalozation is a techinwque often applied as part od the data prepration for the 
# mcahine learning .The goal of teh normalizaion is to change the values of the numeric
# columns in teh dataset to use a common sacale wothout distorting differernces
# in the ranges of the values or lising information

# %%
#  type of normalization 
# minmaxscaling 
# mean normalization
# max absalute scaling
# roubts scaling

# %%
# MinMax Scalling 
# range will be 0-1
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv/wine_data.csv',header = None ,usecols =[0,1,2])
df.columns=['class lable','alchol','malic acid']

# %%
df= df.iloc[1:]
df = df.reset_index(drop =True)

# %%
df
# Out:
#     class lable alchol malic acid
# 0             1  14.23       1.71
# 1             1   13.2       1.78
# 2             1  13.16       2.36
# 3             1  14.37       1.95
# 4             1  13.24       2.59
# ..          ...    ...        ...
# 173           3  13.71       5.65
# 174           3   13.4       3.91
# 175           3  13.27       4.28
# 176           3  13.17       2.59
# 177           3  14.13        4.1
#
# [178 rows x 3 columns]

# %%
sns.kdeplot(pd.to_numeric(df['malic acid']))
# Out:
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='malic acid', ylabel='Density'>

# %%
sns.kdeplot(pd.to_numeric(df['alchol']))
# Out:
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='alchol', ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define the color palette dictionary with all unique values in 'class label' column as keys
color_dict = {1: 'red', 3: 'blue', 2: 'green'}

# Plot the scatterplot with hue
sns.scatterplot(data=df, x='malic acid', y='alchol', hue='class lable', palette=color_dict)

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 8
#       5 color_dict = {1: 'red', 3: 'blue', 2: 'green'}
#       7 # Plot the scatterplot with hue
# ----> 8 sns.scatterplot(data=df, x='malic acid', y='alchol', hue='class lable', palette=color_dict)
#      10 # Display the plot
#      11 plt.show()
#
# File ~/.local/lib/python3.10/site-packages/seaborn/relational.py:744, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     741 variables = _ScatterPlotter.get_semantics(locals())
#     742 p = _ScatterPlotter(data=data, variables=variables, legend=legend)
# --> 744 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     745 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#     746 p.map_style(markers=markers, order=style_order)
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train ,X_test ,y_train ,y_test = train_test_split(df.drop('class lable',axis = 1 ), df['class lable'],test_size =0.3, random_state = 0)

X_train.shape ,X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)

# transform train and test sets 
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled =pd.DataFrame(X_train_scaled ,columns =X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled ,columns =X_test.columns)

# %%
np.round(X_train.describe(),1)
# Out:
#        alchol malic acid
# count     124        124
# unique     97         98
# top     12.08       1.73
# freq        4          4

# %%
np.round(X_train_scaled.describe(),1)
# Out:
#        alchol  malic acid
# count   124.0       124.0
# mean      0.5         0.3
# std       0.2         0.2
# min       0.0         0.0
# 25%       0.4         0.2
# 50%       0.5         0.2
# 75%       0.7         0.5
# max       1.0         1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# Plot scatterplot before scaling
sns.scatterplot(data=X_train, x='alchol', y='malic acid', hue=y_train, ax=ax1)
ax1.set_title('Before Scaling')

# Plot scatterplot after scaling
sns.scatterplot(data=X_train_scaled, x='alchol', y='malic acid', hue=y_train, ax=ax2)
ax2.set_title('After Scaling')

# Display the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Convert 'alcohol' and 'malic acid' columns to numeric
X_train['alchol'] = pd.to_numeric(X_train['alchol'])
X_train['malic acid'] = pd.to_numeric(X_train['malic acid'])

# Create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# Plot KDE plot before scaling
sns.kdeplot(data=X_train['alchol'], ax=ax1)
sns.kdeplot(data=X_train['malic acid'], ax=ax1)
ax1.set_title('Before Scaling')

# Plot KDE plot after scaling
sns.kdeplot(data=X_train_scaled['alchol'], ax=ax2)
sns.kdeplot(data=X_train_scaled['malic acid'], ax=ax2)
ax2.set_title('After Scaling')

# Display the plot
plt.show()
# Out:
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
fig ,(ax1,ax2) = plt.subplots(ncols =2 ,figsize =( 12,5))

#before scaling 
ax1.set_title('Alchol Distribution Before Scaling ')
sns.kdeplot(X_train['alchol'],ax =ax1)

# after scaling 
ax2.set_title('alchol daistribution after the standard scaling')
sns.kdeplot(X_train_scaled['alchol'] ,ax = ax2)
plt.show()
# Out:
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
fig ,(ax1,ax2) = plt.subplots(ncols =2 ,figsize =( 12,5))

#before scaling 
ax1.set_title('Alchol Distribution Before Scaling ')
sns.kdeplot(X_train['malic acid'],ax =ax1)

# after scaling 
ax2.set_title('alchol daistribution after the standard scaling')
sns.kdeplot(X_train_scaled['malic acid'] ,ax = ax2)
plt.show()
# Out:
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/anubhav/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Mean normalization

# %%
# mean centing we move the data at the origin

# %% [markdown]
# # max absolute scalling

# %%
# maxabs is used to dive the curent value with the absoulte value of the x

# %% [markdown]
# # Robus scalling

# %%
# class is used in Robust in sklearn if there is many outliers
