# %%
## matrix used for the effeicieny

# %%
#1. MAE
#2.MSE
#3.RUSE
#R2 SCORE 
# MAE

# %%
# MAE
# mae = from i=1 to n sumeation of mod(yi -yi_pre)

# %%
## MSE Mean Squared Error  for low outliesr
# mse =from i=1 to n sumeation of (yi -yi_pre)^2

# %%
## RMSE root over of sigma 
# rmase = squrt((from i=1 to n sumeation of (yi -yi_pre)^2)/n)

# %%
# R2 SCORE  which shows hoe the model is performing 
# in  the r2 method we calcualate the difference of the  regression line and the mean line     
# r2 = 1(SSR/SSM) SSR =SUM OF SQUARED  error in regression line   AND  SSM = SUM OF  SQUARED  in  MEAN  line

# %%
## ADJUSTED R2 score 
# r2adj = 1-[(1-r2)(n-2) / (n-1-k)]  k = number of columns   r2 =normal r2 score

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('placement_package.csv')

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
 plt.scatter(df['cgpa'],df['package'])
 plt.xlabel('cgpa')
 plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
x = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2 ,random_state =2)

# %% [raw]
# from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train,lr.predict(x_train),color ='red')
plt.xlabel('cgpa')
plt.ylabel('package')
# Out:
# Text(0, 0.5, 'package')

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
y_pred =lr.predict(x_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61])

# %%
print('mean absoulte error',mean_absolute_error(y_test,y_pred))
# Out:
# mean absoulte error 0.2884710931878175

# %%
print('mse ' ,mean_squared_error(y_test,y_pred))
# Out:
# mse  0.12129235313495527

# %%
print('rmse ' ,np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# rmse  0.34827051717731616

# %%
print('r2_score ' ,r2_score(y_test,y_pred))
r2 =r2_score(y_test,y_pred)
# Out:
# r2_score  0.780730147510384

# %%
## adjusted r2 score
x_test.shape
# Out:
# (40, 1)

# %%
1- ((1-r2)*(40-1))/(40-1-1)
# Out:
# 0.7749598882343415

# %%
## adding a random colukn for seeing the change in r2 
new_df1 = df.copy()
new_df1['random_feature'] =np.random.random(200)

new_df1 =new_df1[['cgpa','random_feature','package']]
new_df1.head()
# Out:
#    cgpa  random_feature  package
# 0  6.89        0.307108     3.26
# 1  5.12        0.424610     1.98
# 2  7.82        0.112055     3.25
# 3  7.42        0.559085     3.67
# 4  6.94        0.643490     3.57

# %%
plt.scatter(new_df1['random_feature'],new_df1['package'])
plt.xlabel('random_feature')
plt.ylabel('Package')
# Out:
# Text(0, 0.5, 'Package')

# %%
x = new_df1.iloc[:,0:1]
y = new_df1.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2 ,random_state =2)

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
print('r2_score ',r2_score(y_test,y_pred))
# Out:
# r2_score  0.780730147510384

# %%
1- ((1-r2)*(40-1))/(40-1-1)
# Out:
# 0.7749598882343415
